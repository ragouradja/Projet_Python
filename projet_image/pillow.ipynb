# %%
from PIL import Image 
 
pypy =Image.open('pythoni.png')
display(pypy)

flou = pypy.filter(ImageFilter.BLUR)
display(flou)

flou2 = pypy.filter(ImageFilter.BoxBlur(5))
display(flou2)

flou3 = pypy.filter(ImageFilter.GaussianBlur(5))
display(flou3)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=256x256 at 0x7FA9DA839450>
# <PIL.Image.Image image mode=RGBA size=256x256 at 0x7FA9F0999F50>
# <PIL.Image.Image image mode=RGBA size=256x256 at 0x7FA9DBD5ADD0>
# <PIL.Image.Image image mode=RGBA size=256x256 at 0x7FA9F0987C50>

# %%
from PIL import ImageFont, ImageDraw, ImageEnhance

pyt =Image.open('pythoni.png')

peint = ImageDraw.Draw(pyt)
peint.rectangle(((0, 10), (1000, 10)), fill="black")
display(pyt)

peint.rectangle(((20, 20), (100, 100)), fill="black")
display(pyt)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=256x256 at 0x7FA9D8BA1390>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=256x256 at 0x7FA9D8BA1390>

# %%
pyt =Image.open('pythoni.png')

crea = Image.new('RGBA', (50,50), "black")

display(crea)

peint = ImageDraw.Draw(crea)
peint.text((15, 10), "text")
pyt.paste(crea, (100, 100))

display(crea)
display(pyt)
# Out:
# <PIL.Image.Image image mode=RGBA size=50x50 at 0x7FA9D8BB6310>
# <PIL.Image.Image image mode=RGBA size=50x50 at 0x7FA9D8BB6310>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=256x256 at 0x7FA9D8BD7590>
